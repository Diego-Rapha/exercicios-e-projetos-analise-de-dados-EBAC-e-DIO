# %%
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl import Workbook, load_workbook

# %%
wb = load_workbook("meio_circulante_dados_abertos_1.xlsx")

# %%
for sheet in wb:
  print(sheet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-30f59001b180> in <module>
# ----> 1 for sheet in wb:
#       2   print(sheet)
#
# NameError: name 'wb' is not defined

# %%
ws = wb["meio_circulante_dados_abertos.x"]

# %%
ws['A1'] = "DATA"
ws['B1'] = "FAMÍLIA (ESPÉCIE)"
ws['C1'] = 'REAIS'
ws['D1'] = 'CENTAVOS'
ws['E1'] = 'TIRAGEM'

wb.save('meio_circulante_dados_abertos_1.xlsx')

# %%
df = pd.read_excel("meio_circulante_dados_abertos_1.xlsx")

# %%
df.head()
# Out:
#          DATA            FAMÍLIA (ESPÉCIE)  REAIS  CENTAVOS    TIRAGEM  \
# 0  02/01/1995  Moedas - 1a. Família (inox)      0         1  834342314
# 1  02/01/1995  Moedas - 1a. Família (inox)      0         5  636711876
# 2  02/01/1995  Moedas - 1a. Família (inox)      0        10  583076666
# 3  02/01/1995  Moedas - 1a. Família (inox)      0        25  146883388
# 4  02/01/1995  Moedas - 1a. Família (inox)      0        50  329791540
#
#    Unnamed: 5
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
ws.delete_cols(6)
wb.save('meio_circulante_dados_abertos_1.xlsx')
df = pd.read_excel("meio_circulante_dados_abertos_1.xlsx")

# %%
df.head()
# Out:
#          DATA            FAMÍLIA (ESPÉCIE)  REAIS  CENTAVOS    TIRAGEM
# 0  02/01/1995  Moedas - 1a. Família (inox)      0         1  834342314
# 1  02/01/1995  Moedas - 1a. Família (inox)      0         5  636711876
# 2  02/01/1995  Moedas - 1a. Família (inox)      0        10  583076666
# 3  02/01/1995  Moedas - 1a. Família (inox)      0        25  146883388
# 4  02/01/1995  Moedas - 1a. Família (inox)      0        50  329791540
